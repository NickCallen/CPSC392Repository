# %%
# import necessary packages here
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. Load the pandas library, and alias it so you can use `pd` instead of typing `pandas` each time you need to access the package.
#
# 2. Load the penguin and titanic datasets from GitHub. Store them in `penguins` and `titanic` respectively.
#
# `
# penguin_url = 'https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/penguins.csv'
# titanic_url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
# print("done")
# `
#
# 3. Print the head (first 5 or 6 rows) of each data set.
#
# 4. Store the sex column from the titanic dataset in the variable `sex`. Print it.
#
# 5. Store the 10th row from the penguin dataset in the variable `penguins_10`. Print it.
#
# 6. Grab the age of the 12th person in the titanic dataset and store it in the variable `passenger12`. Print it.
#
# 7. Store the mean age of titanic passengers in the variable `mean_age`, print it.
#
# 8. Create a new column in `penguins` called `bill_ratio` for the penguin dataset that contains the ratio of bill length to bill depth (in otherwords bill length divided by bill depth). Print out this column.
#
# 9. Create a new data frame called `lil_boys` that only contains penguins that have a body mass less than 4000 grams. Print the first 4 rows of this dataframe.
#
# 10. What is the mean bill length for each species of penguin? Store the means in the variables `bl_Adelie`, `bl_Chinstrap` and `bl_Gentoo` respectively. Print them out.
#
# 11. Which class from the titanic dataset had the highest proportion of surviors? Print out the proportion of people who survived for each class.
#
# 12. Is there a difference in the average fare paid between males and females in the titanic dataset? Use pandas to find your answer.
#
# 13. Create a dataframe called `small_penguin` that has all the rows from `penguins` but only the columns `bill_length_mm` ,`bill_depth_mm` , `flipper_length_mm` , and `body_mass_g`

# %%
### YOUR CODE HERE ###
import pandas as pd

# %%
penguins = pd.read_csv('https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/penguins.csv')
penguins.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           3  Adelie  Torgersen             NaN            NaN
# 4           4  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
titanic  = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sex = titanic["sex"]
sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
penguins_10 = penguins.iloc[[10]]
penguins_10
# Out:
#     Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 10          10  Adelie  Torgersen            37.8           17.1
#
#     flipper_length_mm  body_mass_g  sex  year
# 10              186.0       3300.0  NaN  2007

# %%
passanger12 = titanic.iloc[12]["age"]
passanger12
# Out:
# 20.0

# %%
mean_age = titanic["age"].mean()
mean_age
# Out:
# 29.69911764705882

# %%
penguins["bill_ratio"] = penguins["bill_length_mm"]/penguins["bill_depth_mm"]
penguins.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           3  Adelie  Torgersen             NaN            NaN
# 4           4  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year  bill_ratio
# 0              181.0       3750.0    male  2007    2.090909
# 1              186.0       3800.0  female  2007    2.270115
# 2              195.0       3250.0  female  2007    2.238889
# 3                NaN          NaN     NaN  2007         NaN
# 4              193.0       3450.0  female  2007    1.901554

# %%
lil_boys = pd.DataFrame(penguins["body_mass_g"] < 4000.0)
lil_boys.head(4)
# Out:
#    body_mass_g
# 0         True
# 1         True
# 2         True
# 3        False

# %%
Adelie = penguins["species"] == "Adelie"
adeliePenguins  = penguins.loc[Adelie]

# %%
bl_Adelie = adeliePenguins["bill_length_mm"].mean()
bl_Adelie
# Out:
# 38.79139072847684

# %%
Chinstrap = penguins["species"] == "Chinstrap"
chinstrapPenguins  = penguins.loc[Chinstrap]

# %%
bl_Chinstrap = chinstrapPenguins["bill_length_mm"].mean()
bl_Chinstrap
# Out:
# 48.83382352941177

# %%
Gentoo = penguins["species"] == "Gentoo"
gentooPenguins  = penguins.loc[Gentoo]

# %%
bl_Gentoo = gentooPenguins["bill_length_mm"].mean()
bl_Gentoo
# Out:
# 47.504878048780476

# %%
survivors = titanic["survived"] == 1
survivors
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: survived, Length: 891, dtype: bool

# %%
classofSurvivors = titanic.loc[survivors]["class"].max()
classofSurvivors
# Out:
# 'Third'

# %%
males = titanic["sex"] == "male"
maleRiders = titanic[males]
maleRiders
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
maleRiders["fare"].sum()/577
# Out:
# 25.523893414211443

# %%
females = titanic["sex"] == "female"
femaleRiders = titanic[females]
femaleRiders
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
femaleRiders["fare"].sum()/femaleRiders["fare"].count()
# Out:
# 44.47981783439491

# %%
small_penguins = pd.DataFrame([penguins["bill_length_mm"], penguins["bill_depth_mm"], penguins["flipper_length_mm"],penguins["body_mass_g"]])
small_penguins
# Out:
#                       0       1       2    3       4       5       6    \
# bill_length_mm       39.1    39.5    40.3  NaN    36.7    39.3    38.9
# bill_depth_mm        18.7    17.4    18.0  NaN    19.3    20.6    17.8
# flipper_length_mm   181.0   186.0   195.0  NaN   193.0   190.0   181.0
# body_mass_g        3750.0  3800.0  3250.0  NaN  3450.0  3650.0  3625.0
#
#                       7       8       9    ...     334     335     336  \
# bill_length_mm       39.2    34.1    42.0  ...    50.2    45.6    51.9
# bill_depth_mm        19.6    18.1    20.2  ...    18.8    19.4    19.5
# flipper_length_mm   195.0   193.0   190.0  ...   202.0   194.0   206.0
# body_mass_g        4675.0  3475.0  4250.0  ...  3800.0  3525.0  3950.0
#
#                       337     338     339     340     341     342     343
# bill_length_mm       46.8    45.7    55.8    43.5    49.6    50.8    50.2
# bill_depth_mm        16.5    17.0    19.8    18.1    18.2    19.0    18.7
# flipper_length_mm   189.0   195.0   207.0   202.0   193.0   210.0   198.0
# body_mass_g        3650.0  3650.0  4000.0  3400.0  3775.0  4100.0  3775.0
#
# [4 rows x 344 columns]

# %%
small_penguinsT = small_penguins.transpose()
small_penguinsT
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339            55.8           19.8              207.0       4000.0
# 340            43.5           18.1              202.0       3400.0
# 341            49.6           18.2              193.0       3775.0
# 342            50.8           19.0              210.0       4100.0
# 343            50.2           18.7              198.0       3775.0
#
# [344 rows x 4 columns]
